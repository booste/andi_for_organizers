# %%
import andi
import numpy as np
import csv as csv
import numpy as np

from sklearn.metrics import mean_absolute_error
import tensorflow as tf



import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras import losses, metrics

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import LSTM

from keras.layers import Dropout
from keras.layers import Bidirectional
#from keras.models import load_model
from tensorflow.keras.models import load_model
import os
from matplotlib import pyplot as plt
#from data_split import data_split
from many_net import many_net, many_net_diffv, many_net_only_diff, many_net_odcv_hd, many_net_only_diff_cont_varc, many_net_only_diff_cont_varc_2d_4_3d, many_net_only_diff_cont_varc_dim
# Out:
# Using TensorFlow backend.

# %%
os.getcwd()
# Out:
# '/Users/stefabo/Documents/GitHub/eduRNN'

# %% [markdown]
# Importing the data

# %%
import csv
trajs_from_files = csv.reader(open('challenge_for_scoring/task1.txt','r'), delimiter=';', 
                                        lineterminator='\n',quoting=csv.QUOTE_NONNUMERIC)
validation = [[],[],[]]
for trajs in enumerate(trajs_from_files):
    validation[int(trajs[1][0])-1].append(trajs[1][1:])

# %%
len(validation[1])
# Out:
# 10000

# %% [markdown]
# Importing the networks

# %%
centers1d =[25, 50, 65, 75, 125, 165, 225,
            325, 425, 525, 625, 725, 825, 925]
meta_model1d=[]
for i in centers1d: #NB I should go the whole way to 925 and use 25 and 60
    m=load_model('nets/task1/1d/Model_1D_recdout_'+str(i)+'.h5')
    #m=tf.keras.models.load_model('Model_1D_recdout_'+str(i)+'.h5')


    meta_model1d.append(m)

# %%
predictions1d=many_net_only_diff_cont_varc(meta_model1d,validation[0],centers=centers1d)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function _make_execution_function.<locals>.distributed_function at 0x7f87790063b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/beta/tutorials/eager/tf_function#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# ...

# %%
np.save('predictions/task1_pred_1d_final.npy',predictions1d)

# %% [markdown]
# One could also use

# %%
# a, predictions1d_check=many_net_odcv_hd(meta_model1d,validation[0],
#                  centers=centers1d,
#                  dim=1,thr=1e-12,skip=[],min_tr=0,max_tr=1000)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function _make_execution_function.<locals>.distributed_function at 0x7fd2ef1555f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/beta/tutorials/eager/tf_function#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# ...

# %%
# np.save('task1_pred_1d_check.npy',predictions1d_check)

# %%
# predictions1d = np.load('task1_pred_1d_all.npy')

# %%
# predictions1d_check-predictions1d
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
# np.max(np.abs(predictions1d_check-predictions1d))
# Out:
# 0.0

# %%
# np.save('task1_pred_1d_difference.npy',predictions1d_check-predictions1d)

# %% [markdown]
# # 2d case

# %% [markdown]
# Using 1d nets

# %%
a, predictions2d_u1d=many_net_odcv_hd(meta_model1d,validation[1],
                 centers=centers1d,
                 dim=2,thr=1e-12,skip=[],min_tr=0,max_tr=1000)

# %%
np.save('predictions/task1_pred_2d_u1d_final.npy',predictions2d_u1d)

# %%
predictions2d_u1d.shape
# Out:
# (13309,)

# %% [markdown]
# Using 2d nets

# %%
net_centers2d=[25, 65, 125, 225, 325,  525, 725]
meta_model2d=[]
for i in net_centers2d: 
    m=load_model('nets/task1/2d/task1_2D_checkpoint_'+str(i)+'.h5')
    #m=tf.keras.models.load_model('Model_1D_recdout_'+str(i)+'.h5')


    meta_model2d.append(m)

# %%
len(validation[1])
# Out:
# 13309

# %%
predictions2d_u2d = many_net_only_diff_cont_varc_dim(meta_model2d,validation[1],
                                             centers=net_centers2d,dim=2)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function _make_execution_function.<locals>.distributed_function at 0x7f80ff8ebf80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/beta/tutorials/eager/tf_function#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# ...

# %%
np.save('predictions/task1_pred_2d_u2d_final.npy',predictions2d_u2d)

# %% [markdown]
# Classifying which trajectories are LW

# %%
net_centers2d_classi=[25,125, 225,425]
meta_model2d_classi=[]
for i in net_centers2d_classi: #NB I should go the whole way to 925 and use 25 and 60
    m=load_model('nets/task2/2d/task2_2D_checkpoint_'+str(i)+'.h5')
    #m=tf.keras.models.load_model('Model_1D_recdout_'+str(i)+'.h5')


    meta_model2d_classi.append(m)

# %%
classi_2d=many_net_only_diff_cont_varc_dim(meta_model2d_classi,validation[1],
                                           centers=net_centers2d_classi,dim=2)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function _make_execution_function.<locals>.distributed_function at 0x7fdde45f8cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/beta/tutorials/eager/tf_function#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# ...

# %%
classi_2d=classi_2d.reshape(-1,5)

# %%
classi2d_num=np.argmax(classi_2d,axis=1)

# %%
np.save('predictions/task1_classi2d.npy',classi2d_num)

# %%
aa=classi2_num!=3

# %% [markdown]
# # 3d case

# %%
a3, predictions3d_u1d=many_net_odcv_hd(meta_model1d,validation[2],
                 centers=centers1d,
                 dim=3,thr=1e-12,skip=[],min_tr=0,max_tr=1000)

# %%
np.save('predictions/task1_pred_3d_u1d_final.npy',predictions3d_u1d)

# %% [markdown]
# 3d using 2d nets

# %%
predictions3d_u2d = many_net_only_diff_cont_varc_2d_4_3d(meta_model2d,validation[2],
                 centers=net_centers2d,
                 skip=[],min_tr=0,max_tr=1000)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function _make_execution_function.<locals>.distributed_function at 0x7fd8032fbb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/beta/tutorials/eager/tf_function#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# ...

# %%
np.save('predictions/task1_predictions3d_u2d_final.npy',predictions3d_u2d)

# %% [markdown]
# Classify the trajectories using nets trained on 2d data on the 2d projections of the 3d data

# %%
classi3d_u2d = many_net_only_diff_cont_varc_2d_4_3d(meta_model2d_classi,validation[2],
                 centers=net_centers2d_classi,
                 skip=[],min_tr=0,max_tr=1000)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function _make_execution_function.<locals>.distributed_function at 0x7f8f181b3440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/beta/tutorials/eager/tf_function#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# ...

# %%
classi3d_u2d = classi3d_u2d.reshape(-1,5)
num_classi3d_u2d = np.argmax(classi3d_u2d,axis=1)

# %%
np.save('predictions/task1_classi3d_u2d.npy',num_classi3d_u2d)
